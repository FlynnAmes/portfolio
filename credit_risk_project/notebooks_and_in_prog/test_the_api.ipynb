# %%
import requests

# %%
feature_dict = { 
             'rev_util': float(0.2),
             'age': int(37),
             'late_30_59': int(0), 
             'debt_ratio': float(0.2), 
             'open_credit': int(1),
             'late_90': int(0), 
             'dependents': int(2), 
            'real_estate': int(0),  
            'late_60_89': int(0), 
                 'monthly_inc': float(1000),
                }

# %%
response = requests.post('http://127.0.0.1:8000/predict/', json=feature_dict)
print(response.content)
# Out:
# b'{"inference":1,"probability":0.48891179854315386}'
